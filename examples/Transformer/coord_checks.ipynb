# %%
import pandas as pd

df = pd.read_pickle('/home/berlin/mup/examples/Transformer/coord_checks/μp_trsfmr_adam_coord.pkl')
# df.to_csv('/home/berlin/mup/examples/Transformer/coord_checks/μp_trsfmr_adam_coord.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = df[df['module'].isin(['encoder', 'transformer_encoder.layers.0', 'transformer_encoder.layers.1.linear1', 'transformer_encoder.layers.1.self_attn:out[1]'])]
sns.relplot(data=df, x='width', y='l1', hue='module', legend='auto', col='t', kind='line')
plt.loglog(base=2)
# Out:
# []
